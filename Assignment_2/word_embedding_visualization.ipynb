# %%
# %pip install gdown
# %gdown --id 1ajm_Az1wn16aI9b8kD1ao3efRiB1KJCz
# %gdown --id 1XBbRmnhaI17OLh2FqhUdQdn2rq2KJJIq
# Out:
# Collecting gdown
#   Downloading gdown-5.1.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting beautifulsoup4 (from gdown)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting filelock (from gdown)
#   Downloading filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests[socks] in /Users/kish/miniconda3/lib/python3.11/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /Users/kish/miniconda3/lib/python3.11/site-packages (from gdown) (4.65.0)
# Collecting soupsieve>1.2 (from beautifulsoup4->gdown)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kish/miniconda3/lib/python3.11/site-packages (from requests[socks]->gdown) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kish/miniconda3/lib/python3.11/site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kish/miniconda3/lib/python3.11/site-packages (from requests[socks]->gdown) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kish/miniconda3/lib/python3.11/site-packages (from requests[socks]->gdown) (2023.11.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/kish/miniconda3/lib/python3.11/site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading gdown-5.1.0-py3-none-any.whl (17 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 2.3 MB/s eta 0:00:00 0:00:01
# Downloading filelock-3.13.1-py3-none-any.whl (11 kB)
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, filelock, beautifulsoup4, gdown
# Successfully installed beautifulsoup4-4.12.3 filelock-3.13.1 gdown-5.1.0 soupsieve-2.5
# Note: you may need to restart the kernel to use updated packages.
# UsageError: Line magic function `%gdown` not found.

# %%
import pickle
import pandas as pd
import numpy as np
with open('EmbeddingText_edited.pkl', 'rb') as f:
    text_embedding = pickle.load(f)
y_actual=list(pd.read_csv('encoded_books_data.csv')['Book_Name'])

# %%
import plotly.express as px
from sklearn.decomposition import PCA
pca=PCA(n_components=2,)
embedding=text_embedding.copy()

for key in embedding.keys():
  embedding[key]=pca.fit_transform(embedding[key])
  df=pd.DataFrame({'PCA1':embedding[key][:,0],'PCA2':embedding[key][:,1],'Target':y_actual})
  fig = px.scatter(data_frame =df, x='PCA1', y='PCA2', color='Target')
  fig.update_layout(title={'text':f'{key}','x':0.5},height=500,width=700)
  fig.show()
